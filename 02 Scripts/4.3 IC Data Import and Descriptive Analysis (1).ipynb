# %% [markdown]
# ## Importing Pandas, Numpy and OS

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Linking Datat to Jupyter

# %%
df = pd.read_csv(r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original\orders.csv', index_col = False)

# %% [markdown]
# ## Turning Folder Path Into a String

# %%
x = r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original\orders.csv'

# %%
type (x)
# Out:
# str

# %% [markdown]
# ## Importing orders.csv using os library and vars_list

# %%
df = pd.read_csv(r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original\orders.csv', index_col = False)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
print (vars_list)
# Out:
# ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
path = r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original'

# %%
print (path)
# Out:
# C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original

# %%
df = pd.read_csv(os.path.join(path, 'orders.csv'), usecols = vars_list)

# %% [markdown]
# ## Printing the first 5 rows of data

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Importing products as df_prods

# %%
df_prods = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %%
path = r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original'

# %%
df = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %%
df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## Printing the frist 20 rows

# %%
df.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %% [markdown]
# ## Printing last 35 rows

# %%
df.tail(35)
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %% [markdown]
# ## Maximum value of aisle_id

# %%
max_aisle_id = df['aisle_id'].max()
print(max_aisle_id)
# Out:
# 134

# %%
df['department_id'].dtype
# Out:
# dtype('int64')

# %%
df = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %% [markdown]
# ## importing pandas, numpy and df_prods again

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\BaratSakhizada\Desktop\Achievement 4\02 Data\Original'

# %%
df_prods = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %% [markdown]
# ## Printing the names of the columns in df_prods dataframe

# %%
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %% [markdown]
# ## Print the number of rows and columns in the df_prods dataframe.

# %%
df_prods.shape
# Out:
# (49693, 5)
